# %% [markdown]
# <a href="https://colab.research.google.com/github/zjpn2gm7p8-hash/bro-shola/blob/main/ENT%20assignment%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name='bola'

# %%
Age='23'

# %%
department='business education'

# %%
mathematicsscore=72

# %%
python=82

# %%
stastics=68

# %%
totalscore=255

# %%
averagescore=75.0

# %%
highestscore=82

# %%
lowestscore=68

# %%
print (name)
# Out:
# bola

# %%
print (type(name))
# Out:
# <class 'str'>

# %%
print (type(Age))
print (averagescore)
print (type(averagescore))
print (type(passed))
# Out:
# <class 'str'>
# 75.0
# <class 'float'>
# <class 'bool'>

# %%
passed=True

# %%
print ('Age')
# Out:
# Age

# %%
print (type(python))
# Out:
# <class 'int'>

# %%
print (type(highestscore))
# Out:
# <class 'int'>

# %%
print (type(passed))
print (python+stastics)
print (python/stastics)
print (python>stastics)
print (python<stastics)
print (python==stastics)
print (python*stastics)
# Out:
# <class 'bool'>
# 150
# 1.2058823529411764
# True
# False
# False
# 5576
